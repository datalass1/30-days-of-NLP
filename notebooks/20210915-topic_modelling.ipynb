# %% [markdown]
# ### Topic Modeling: Latent Dirichlet Allocation (LDA) using Gensim

# %% [markdown]
# data: https://www.kaggle.com/yufengdev/bbc-fulltext-and-category/version/2?select=bbc-text.csv
#
# tutorials: https://www.linkedin.com/pulse/nlp-a-complete-guide-topic-modeling-latent-dirichlet-sahil-m/ & Chpt 7 Practical Natural Language Processing

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download('stopwords')
import pandas as pd
import gensim
from gensim.models import LdaModel
from gensim.corpora import Dictionary
from pprint import pprint
import spacy  # for lemmatization
# Out:
# [nltk_data] Downloading package stopwords to /home/rachel/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /home/rachel/miniconda3/envs/nlp-genism/lib/python3.7/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
df = pd.read_csv('Data/bbc-text.csv')
df.head()
# Out:
#         category                                               text
# 0           tech  tv future in the hands of viewers with home th...
# 1       business  worldcom boss  left books alone  former worldc...
# 2          sport  tigers wary of farrell  gamble  leicester say ...
# 3          sport  yeading face newcastle in fa cup premiership s...
# 4  entertainment  ocean s twelve raids box office ocean s twelve...

# %%
print(f'Number of documents: {len(df)}')
# Out:
# Number of documents: 2225

# %% [markdown]
# ### Data Cleaning

# %%
#tokenize, remove stopwords, non-alphabetic words, lowercase
def preprocess(textstring):
    stops =  set(stopwords.words('english'))
    tokens = word_tokenize(textstring) 
    return [token.lower() for token in tokens if token.isalpha() 
          and token not in stops]

data = []
for s in df['text']:
    data_words = preprocess(s)
    data.append(data_words)

# %%
# Are their any weird characters?
regexp = re.compile('[^a-zA-Z]+') # ^ means not a-z or A-Z
print(f'Number of weird characters: {len([s for text in data for s in text if regexp.search(s)])}')
# Out:
# Number of weird characters: 0

# %% [markdown]
# All text is alphabetic with no special characters or numbers, we don't have to do any further text cleaning.
#
# For future reference I should try SpaCy's rule-based matching: "It is like Regular Expressions on steroids." (https://www.analyticsvidhya.com/blog/2020/03/spacy-tutorial-learn-natural-language-processing/).... the spaCy matcher not only uses the text patterns but lexical properties of the word, such as part of speech (POS) tags, dependency tags, lemma, etc.

# %% [markdown]
# #### Lemmatize Tokens using spaCy.
#
# The en_core_web_sm model is a small English pipeline trained on written web text and is used to perform several NLP related tasks such as part-of-speech tagging, named entity recognition and dependency parsing.
#
# The assigned `nlp` object is a pipeline of several text pre-processing operation through which the input text string has to go through.

# %%
# ! python -m spacy download en_core_web_sm
nlp = spacy.load("en_core_web_sm")
def lemmatization(data, allowed_postags=['NOUN']):
    texts_out = []
    for text in data:
        for s in text:
            doc = nlp(''.join(s))
            texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

data_lemmatized = lemmatization(data, allowed_postags=['NOUN'])

# %%
data_lemmatized
# Out:
# [['tv'],
#  ['future'],
#  ['hand'],
#  ['viewer'],
#  ['home'],
#  [],
#  ['system'],
#  ['plasma'],
#  ['tv'],
#  [],
#  ['video'],
#  ['recorder'],
#  [],
#  [],
#  ['room'],
#  ['way'],
#  ['people'],
#  [],
#  ['tv'],
#  [],
#  [],
#  [],
#  ['year'],
#  ['time'],
#  [],
#  ['expert'],
#  ['panel'],
#  [],
#  [],
#  ['consumer'],
#  ['electronic'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['technology'],
#  ['impact'],
#  [],
#  [],
#  ['pastime'],
#  [],
#  [],
#  [],
#  ['programme'],
#  ['content'],
#  [],
#  ['viewer'],
#  [],
#  ['home'],
#  ['network'],
#  ['cable'],
#  ['satellite'],
#  ['telecom'],
#  ['company'],
#  ['broadband'],
#  ['service'],
#  ['provider'],
#  ['front'],
#  ['room'],
#  [],
#  ['device'],
#  [],
#  ['technology'],
#  ['ce'],
#  [],
#  [],
#  ['video'],
#  ['recorder'],
#  ['dvr'],
#  ['pvr'],
#  ['box'],
#  [],
#  [],
#  [],
#  [],
#  ['system'],
#  [],
#  ['people'],
#  ['record'],
#  ['store'],
#  [],
#  ['pause'],
#  [],
#  ['wind'],
#  ['tv'],
#  ['programme'],
#  [],
#  [],
#  ['technology'],
#  [],
#  [],
#  [],
#  ['tv'],
#  [],
#  ['tv'],
#  ['set'],
#  [],
#  ['business'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['lack'],
#  ['programming'],
#  ['people'],
#  [],
#  ['wind'],
#  ['advert'],
#  [],
#  [],
#  [],
#  ['network'],
#  [],
#  ['schedule'],
#  [],
#  [],
#  ['entertainment'],
#  [],
#  ['network'],
#  ['cable'],
#  ['satellite'],
#  ['company'],
#  [],
#  [],
#  ['term'],
#  ['advertising'],
#  ['revenue'],
#  [],
#  ['brand'],
#  ['identity'],
#  [],
#  ['loyalty'],
#  ['channel'],
#  [],
#  [],
#  [],
#  ['technology'],
#  ['moment'],
#  [],
#  ['concern'],
#  [],
#  [],
#  [],
#  [],
#  ['uptake'],
#  ['service'],
#  [],
#  [],
#  ['today'],
#  [],
#  [],
#  ['month'],
#  ['year'],
#  ['time'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['news'],
#  ['website'],
#  [],
#  [],
#  ['issue'],
#  [],
#  ['advertising'],
#  ['revenue'],
#  [],
#  [],
#  ['issue'],
#  ['moment'],
#  [],
#  [],
#  ['broadcaster'],
#  ['brand'],
#  ['loyalty'],
#  [],
#  [],
#  [],
#  ['content'],
#  ['brand'],
#  [],
#  ['network'],
#  ['brand'],
#  [],
#  [],
#  ['hanlon'],
#  ['brand'],
#  ['communication'],
#  ['firm'],
#  ['starcom'],
#  [],
#  ['reality'],
#  ['broadband'],
#  ['connection'],
#  [],
#  ['producer'],
#  ['content'],
#  [],
#  ['challenge'],
#  [],
#  [],
#  ['programme'],
#  [],
#  ['choice'],
#  [],
#  [],
#  ['stacey'],
#  [],
#  [],
#  ['vice'],
#  ['president'],
#  ['tv'],
#  [],
#  ['tv'],
#  ['group'],
#  ['way'],
#  ['people'],
#  [],
#  ['content'],
#  [],
#  [],
#  [],
#  ['tv'],
#  ['viewer'],
#  [],
#  ['network'],
#  [],
#  ['term'],
#  ['channel'],
#  [],
#  [],
#  ['leaf'],
#  [],
#  ['book'],
#  ['search'],
#  ['engine'],
#  ['future'],
#  [],
#  [],
#  ['help'],
#  ['people'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['model'],
#  [],
#  [],
#  [],
#  [],
#  ['generation'],
#  [],
#  [],
#  [],
#  ['gadget'],
#  [],
#  [],
#  ['suit'],
#  [],
#  ['panel'],
#  [],
#  [],
#  ['generation'],
#  [],
#  [],
#  ['schedule'],
#  [],
#  ['brand'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['choice'],
#  [],
#  ['hand'],
#  [],
#  ['hanlon'],
#  [],
#  [],
#  ['kid'],
#  ['diaper'],
#  [],
#  ['button'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['hanlon'],
#  [],
#  ['consumer'],
#  [],
#  ['market'],
#  [],
#  [],
#  ['gadget'],
#  ['technology'],
#  [],
#  ['ce'],
#  [],
#  [],
#  ['experience'],
#  ['tv'],
#  ['set'],
#  [],
#  [],
#  [],
#  ['model'],
#  [],
#  ['liquid'],
#  ['crystal'],
#  [],
#  ['tv'],
#  [],
#  ['dvr'],
#  ['capability'],
#  [],
#  [],
#  [],
#  ['box'],
#  [],
#  ['example'],
#  [],
#  [],
#  ['humax'],
#  [],
#  ['tv'],
#  [],
#  ['dvr'],
#  ['dvd'],
#  [],
#  [],
#  [],
#  [],
#  ['satellite'],
#  ['tv'],
#  ['company'],
#  ['directtv'],
#  [],
#  [],
#  [],
#  ['dvr'],
#  [],
#  [],
#  ['capability'],
#  ['instant'],
#  ['replay'],
#  ['search'],
#  ['function'],
#  [],
#  ['pause'],
#  ['rewind'],
#  ['tv'],
#  ['hour'],
#  [],
#  ['chief'],
#  ['bill'],
#  ['gate'],
#  [],
#  [],
#  ['speech'],
#  ['partnership'],
#  [],
#  [],
#  [],
#  [],
#  ['people'],
#  [],
#  [],
#  ['programme'],
#  ['window'],
#  [],
#  [],
#  ['device'],
#  [],
#  [],
#  [],
#  [],
#  ['multimedia'],
#  ['people'],
#  [],
#  [],
#  [],
#  ['worldcom'],
#  ['boss'],
#  [],
#  ['book'],
#  [],
#  [],
#  ['worldcom'],
#  ['boss'],
#  [],
#  ['ebber'],
#  [],
#  [],
#  ['fraud'],
#  [],
#  [],
#  [],
#  ['decision'],
#  ['witness'],
#  [],
#  ['juror'],
#  [],
#  [],
#  [],
#  ['comment'],
#  [],
#  ['defence'],
#  ['lawyer'],
#  [],
#  [],
#  ['ebber'],
#  [],
#  ['worldcom'],
#  ['problem'],
#  ['phone'],
#  ['company'],
#  [],
#  ['prosecutor'],
#  [],
#  ['loss'],
#  [],
#  [],
#  ['firm'],
#  ['share'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['fraud'],
#  [],
#  ['prosecutor'],
#  [],
#  ['defence'],
#  ['lawyer'],
#  [],
#  [],
#  [],
#  ['distance'],
#  ['client'],
#  ['allegation'],
#  [],
#  ['examination'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['ebber'],
#  [],
#  [],
#  ['decision'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['ebber'],
#  [],
#  [],
#  ['entry'],
#  ['worldcom'],
#  ['book'],
#  [],
#  [],
#  [],
#  [],
#  ['witness'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['entry'],
#  ['request'],
#  [],
#  ['worldcom'],
#  ['chief'],
#  [],
#  ['officer'],
#  [],
#  [],
#  ['defence'],
#  ['lawyer'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['fraud'],
#  [],
#  [],
#  ['trial'],
#  ['mastermind'],
#  [],
#  ['worldcom'],
#  [],
#  ['house'],
#  ['card'],
#  [],
#  ['ebber'],
#  ['team'],
#  [],
#  [],
#  [],
#  [],
#  ['boss'],
#  ['admission'],
#  [],
#  ['graduate'],
#  ['economist'],
#  [],
#  ['ability'],
#  [],
#  ['ebber'],
#  [],
#  ['worldcom'],
#  [],
#  [],
#  ['telecom'],
#  ['giant'],
#  ['investor'],
#  [],
#  [],
#  ['worldcom'],
#  ['problem'],
#  [],
#  [],
#  ['competition'],
#  [],
#  ['telecom'],
#  ['boom'],
#  [],
#  ['firm'],
#  [],
#  [],
#  ['shareholder'],
#  [],
#  ['worker'],
#  [],
#  ['job'],
#  [],
#  ['ebber'],
#  ['trial'],
#  [],
#  [],
#  [],
#  ['month'],
#  [],
#  [],
#  [],
#  ['ceo'],
#  [],
#  [],
#  ['jail'],
#  ['sentence'],
#  [],
#  [],
#  ['innocence'],
#  ['tiger'],
#  [],
#  [],
#  [],
#  ['leicester'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['rugby'],
#  [],
#  ['captain'],
#  [],
#  [],
#  ['code'],
#  [],
#  [],
#  [],
#  ['process'],
#  [],
#  ['way'],
#  [],
#  [],
#  [],
#  ['stage'],
#  ['tiger'],
#  ['boss'],
#  [],
#  ['well'],
#  [],
#  [],
#  ['radio'],
#  ['leicester'],
#  ['moment'],
#  [],
#  ['lot'],
#  ['unknown'],
#  [],
#  [],
#  [],
#  [],
#  ['situation'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['knee'],
#  ['problem'],
#  ['operation'],
#  ['knee'],
#  [],
#  ['week'],
#  [],
#  [],
#  [],
#  [],
#  ['month'],
#  ['leicester'],
#  ['saracen'],
#  [],
#  ['head'],
#  ['list'],
#  ['rugby'],
#  ['union'],
#  ['club'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['game'],
#  [],
#  [],
#  ['union'],
#  ['well'],
#  [],
#  [],
#  [],
#  [],
#  ['back'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['step'],
#  [],
#  ['union'],
#  [],
#  ['centre'],
#  [],
#  ['well'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['position'],
#  [],
#  ['row'],
#  [],
#  [],
#  ['rugby'],
#  [],
#  ['skill'],
#  [],
#  [],
#  ['jury'],
#  [],
#  [],
#  [],
#  ['club'],
#  ['balance'],
#  [],
#  ['cost'],
#  [],
#  ['option'],
#  [],
#  ['replacement'],
#  [],
#  ['face'],
#  ['newcastle'],
#  [],
#  [],
#  ['premiership'],
#  ['side'],
#  ['newcastle'],
#  [],
#  ['face'],
#  ['trip'],
#  ['ryman'],
#  ['premier'],
#  [],
#  ['leader'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['game'],
#  [],
#  [],
#  [],
#  ['potential'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['conference'],
#  ['side'],
#  ['exeter'],
#  ['city'],
#  [],
#  ['doncaster'],
#  [],
#  ['travel'],
#  [],
#  ['trafford'],
#  [],
#  ['holder'],
#  ['manchester'],
#  [],
#  [],
#  ['arsenal'],
#  [],
#  ['home'],
#  [],
#  ['chelsea'],
#  [],
#  ['host'],
#  [],
#  ['side'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['goalless'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['leader'],
#  [],
#  [],
#  ['replay'],
#  [],
#  [],
#  ['team'],
#  [],
#  [],
#  ['number'],
#  ['premiership'],
#  ['team'],
#  ['face'],
#  [],
#  [],
#  ['game'],
#  ['championship'],
#  ['side'],
#  ['weekend'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['travel'],
#  [],
#  ['crystal'],
#  ['palace'],
#  [],
#  ['sunderland'],
#  [],
#  ['face'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['villa'],
#  [],
#  [],
#  [],
#  ['premiership'],
#  ['struggler'],
#  ['norwich'],
#  ['blackburn'],
#  [],
#  [],
#  [],
#  [],
#  ['ham'],
#  ['cardiff'],
#  [],
#  ['north'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['side'],
#  [],
#  [],
#  [],
#  ['season'],
#  ['middlesbrough'],
#  [],
#  [],
#  [],
#  [],
#  ['nott'],
#  ['county'],
#  [],
#  [],
#  [],
#  [],
#  ['hart'],
#  ['lane'],
#  ['arsenal'],
#  [],
#  [],
#  [],
#  [],
#  ['middlesbrough'],
#  ['man'],
#  [],
#  [],
#  ['exeter'],
#  [],
#  [],
#  [],
#  ['leicester'],
#  [],
#  ['blackpool'],
#  [],
#  [],
#  [],
#  ['sunderland'],
#  [],
#  ['crystal'],
#  ['palace'],
#  ['wolf'],
#  [],
#  ['millwall'],
#  [],
#  [],
#  ['newcastle'],
#  ['hull'],
#  [],
#  ['colchester'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['hartlepool'],
#  [],
#  [],
#  [],
#  [],
#  ['don'],
#  [],
#  ['peterborough'],
#  [],
#  [],
#  ['man'],
#  ['city'],
#  ['chelsea'],
#  [],
#  [],
#  ['cardiff'],
#  [],
#  ['blackburn'],
#  [],
#  [],
#  ['rochdale'],
#  [],
#  ['ham'],
#  [],
#  ['norwich'],
#  [],
#  [],
#  [],
#  [],
#  ['villa'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['yeovil'],
#  [],
#  [],
#  [],
#  ['bournemouth'],
#  [],
#  ['chester'],
#  ['coventry'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['portsmouth'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['qpr'],
#  [],
#  ['nottm'],
#  ['forest'],
#  [],
#  [],
#  ['match'],
#  [],
#  ['weekend'],
#  [],
#  ['ocean'],
#  [],
#  ['raid'],
#  ['box'],
#  ['office'],
#  ['ocean'],
#  [],
#  ['crime'],
#  ['caper'],
#  ['sequel'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['robert'],
#  [],
#  [],
#  ['number'],
#  [],
#  [],
#  ['box'],
#  ['office'],
#  ['chart'],
#  [],
#  ['weekend'],
#  ['ticket'],
#  ['sale'],
#  [],
#  ['studio'],
#  [],
#  ['sequel'],
#  [],
#  ['master'],
#  ['criminal'],
#  [],
#  [],
#  [],
#  [],
#  ['heist'],
#  [],
#  [],
#  ...]
